# %%
'''测试套件
测试失败，估计是依赖不全
'''
import pandas as pd
pd.test()
# Out:
# running: pytest --skip-slow --skip-network --skip-db C:\ProgramData\Anaconda3\envs\ai_learning\lib\site-packages\pandas
# ================================================================== test session starts ===================================================================
# platform win32 -- Python 3.7.0, pytest-6.2.3, py-1.10.0, pluggy-0.13.1
# rootdir: C:\
# plugins: hypothesis-6.12.0
# collected 152884 items / 18 skipped / 152866 selected
#
# ..\..\..\..\..\..\ProgramData\Anaconda3\envs\ai_learning\lib\site-packages\pandas\tests\test_aggregation.py ........                                [  0%]
# ..\..\..\..\..\..\ProgramData\Anaconda3\envs\ai_learning\lib\site-packages\pandas\tests\test_algos.py ............................................. [  0%]
# ..................................................................................................................sss........ss.................... [  0%]
# ...
